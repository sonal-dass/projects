# %% [markdown]
# # Avacado Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/avocado.csv',sep=",")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1               1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2               2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3               3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4               4  11/29/2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7    2/4/2018          1.63      17074.83  2046.96    1529.20
# 18245           8   1/28/2018          1.71      13888.04  1191.70    3431.50
# 18246           9   1/21/2018          1.87      13766.76  1191.92    2452.79
# 18247          10   1/14/2018          1.93      16205.22  1527.63    2981.04
# 18248          11    1/7/2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# # Dataset Attributes
#
# Input variables:Date - The date of the observation AveragePrice - the average price of a single avocado type - conventional or organic year - the year Region - the city or region of the observation Total Volume - Total number of avocados sold 4046 - Total number of avocados with PLU 4046 sold 4225 - Total number of avocados with PLU 4225 sold 4770 - Total number of avocados with PLU 4770 sold
#
# Output variables: region & average price
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Removing blank rows i.e. empty rows.

df1 = df[df.notnull().any(axis=1)]

# %%
df1.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  12/27/2015          1.33      64236.62  1036.74   54454.85
# 1           1  12/20/2015          1.35      54876.98   674.28   44638.81
# 2           2  12/13/2015          0.93     118220.22   794.70  109149.67
# 3           3   12/6/2015          1.08      78992.15  1132.00   71976.41
# 4           4  11/29/2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df1.shape
# Out:
# (18249, 14)

# %%
#Removing Unnamed: 0 column becuase it's not in our problem statement as well as it have repetative values 0-52, which is not going to help in prediction

df1.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df1.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  12/27/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  12/20/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  12/13/2015          0.93     118220.22   794.70  109149.67  130.50
# 3   12/6/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  11/29/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df1.shape
# Out:
# (18249, 13)

# %%
df1.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# # Univariate Analysis

# %%
print("Total number of Regions are = ",len(df['region'].unique()))
plt.figure(figsize = (12,7))
ax = sns.countplot(x="region", data=df1)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.title("Avacado sales in different Regions", fontsize = 20)
plt.show()
# Out:
# Total number of Regions are =  54

# %% [markdown]
# no variation in sales in different regions

# %%
plt.figure(figsize = (10,5))
ax = sns.countplot(x="type", data=df1)
plt.title("Avacado sales product type", fontsize = 20)
plt.show()

# %% [markdown]
# Avacado have only 2 type of product which is conventional andorganic

# %%
sns.countplot(x='year', data=df1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [markdown]
# maximum sales of avacado in 2017 and minimum in 2018

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = 'AveragePrice', y = 'Total Volume', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
df1['Date'] = pd.to_datetime(df1['Date'], errors='coerce')
plt.figure(figsize = (10,5))
ax = sns.lineplot(x="Date",y="AveragePrice",  data=df1)
plt.title("Fluctuation of Price with respect to date", fontsize = 18)
plt.show()

# %%
plt.figure(figsize = (12,7))
ax = sns.lineplot(x="Date",y="4046",  data=df1)
plt.title("Total number of avocados with PLU 4046 sold with respect to date", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (20,5))
ax = sns.lineplot(x="Date",y="4225",  data=df1)
plt.title("Total number of avocados with PLU 4225 sold with respect to date", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (20,5))
ax = sns.lineplot(x="Date",y="4770",  data=df1)
plt.title("Total number of avocados with PLU 4770 sold with respect to date", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = 'AveragePrice', y = 'Total Bags', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Bags'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = '4046', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4046'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = '4225', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4225'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = '4770', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4770'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = 'Small Bags', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Small Bags'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = 'Large Bags', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Large Bags'>

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'AveragePrice', y = 'XLarge Bags', data = df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='XLarge Bags'>

# %%
fig = plt.figure(figsize = (10,8))
ax=sns.barplot(x = 'region', y = 'AveragePrice', data = df1)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Albany'),
#  Text(1, 0, 'Atlanta'),
#  Text(2, 0, 'BaltimoreWashington'),
#  Text(3, 0, 'Boise'),
#  Text(4, 0, 'Boston'),
#  Text(5, 0, 'BuffaloRochester'),
#  Text(6, 0, 'California'),
#  Text(7, 0, 'Charlotte'),
#  Text(8, 0, 'Chicago'),
#  Text(9, 0, 'CincinnatiDayton'),
#  Text(10, 0, 'Columbus'),
#  Text(11, 0, 'DallasFtWorth'),
#  Text(12, 0, 'Denver'),
#  Text(13, 0, 'Detroit'),
#  Text(14, 0, 'GrandRapids'),
#  Text(15, 0, 'GreatLakes'),
#  Text(16, 0, 'HarrisburgScranton'),
#  Text(17, 0, 'HartfordSpringfield'),
#  Text(18, 0, 'Houston'),
#  Text(19, 0, 'Indianapolis'),
#  Text(20, 0, 'Jacksonville'),
#  Text(21, 0, 'LasVegas'),
#  Text(22, 0, 'LosAngeles'),
#  Text(23, 0, 'Louisville'),
#  Text(24, 0, 'MiamiFtLauderdale'),
#  Text(25, 0, 'Midsouth'),
#  Text(26, 0, 'Nashville'),
#  Text(27, 0, 'NewOrleansMobile'),
#  Text(28, 0, 'NewYork'),
#  Text(29, 0, 'Northeast'),
#  Text(30, 0, 'NorthernNewEngland'),
#  Text(31, 0, 'Orlando'),
# ...

# %% [markdown]
# # Multi-Variate Analysis

# %%
fig=plt.figure(figsize=(20,10))
hc=df1.corr(method='pearson')
sns.heatmap(hc,annot=True,cmap="Blues",linewidths=.1, annot_kws={"size": 10})
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# There is not much corelation between Average Price and any other column.

# %%
#Correlation with AveragePrice with respect to attributes
df1.corrwith(df1.AveragePrice).plot.bar(
        figsize = (20, 8), title = "Correlation with Age Graph", fontsize = 12,
        rot = 30, grid = True)
# Out:
# <AxesSubplot:title={'center':'Correlation with Age Graph'}>

# %% [markdown]
# year correlated with average price

# %% [markdown]
# # Data Cleaning

# %%
#Converting Date to ordinal for ease of prediction

import datetime as dt

df1['Date'] = pd.to_datetime(df1['Date'])
df1['Date'] = df1['Date'].map(dt.datetime.toordinal)

df1.head() #Checking top 5 rows of dataset
# Out:
#      Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0  735959          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1  735952          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2  735945          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3  735938          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4  735931          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df1.dtypes
# Out:
# Date              int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#Year is same as date-year, we can drop it.

df1.drop('year', axis=1, inplace=True)

# %%
df1['type'].unique() #Checking the number of unique values in type column
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
#df1['type'] only have 2 value across all the rows, and equally impact the sales which will not help us to predict.

df1.drop('type', axis=1, inplace=True)

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() #Initlize LabelEncoder to le 
#df1["region"] = le.fit_transform(df1["region"])

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
df1["region"] = enc.fit_transform(df1["region"].values.reshape(-1,1))

# %%
df1.head()
# Out:
#      Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0  735959          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1  735952          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2  735945          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3  735938          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4  735931          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  region
# 0     8603.62       93.25          0.0     0.0
# 1     9408.07       97.49          0.0     0.0
# 2     8042.21      103.14          0.0     0.0
# 3     5677.40      133.76          0.0     0.0
# 4     5986.26      197.69          0.0     0.0

# %%
#shuffling the dataset
#This will Shuffle our dataset and it will avoid biasness of prediction

df1 = df1.sample(frac=1,random_state=0)

# %%
df1.head()
# Out:
#          Date  AveragePrice  Total Volume       4046       4225      4770  \
# 9181   735938          1.48       4400.25    1358.53    1735.98      0.00
# 1013   735784          1.05     190716.43    4890.33  119457.27  13495.86
# 14625  736043          1.27    1045450.41  105069.07  352698.21   9425.64
# 15234  736582          2.15       9883.59     313.75    4230.58      0.00
# 18247  736708          1.93      16205.22    1527.63    2981.04    727.01
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  region
# 9181      1305.74      130.00     1175.74         0.00     1.0
# 1013     52872.97    30631.37    21037.53      1204.07    19.0
# 14625   578257.49   252881.52   325375.97         0.00    51.0
# 15234     5339.26     2166.91     3172.35         0.00     9.0
# 18247    10969.54    10919.54       50.00         0.00    53.0

# %%
df1.skew()
# Out:
# Date             0.000117
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# region           0.000030
# dtype: float64

# %%
#Reducing the skewness of Total Volume using log

df1['Total Volume']=np.log(df1['Total Volume'])

# %%
df1['Total Volume'].skew()
# Out:
# 0.08795448426312666

# %%
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in df1.columns:
    if df1[i].dtype != "object":
        if ((len(pd.unique(df1[i]))) > 2):
            if abs(df1.loc[:,i].skew())>0.5:
                df1.loc[:,i]=PT.fit_transform(df1.loc[:,i].values.reshape(-1,1))

# %%
df1.skew()
# Out:
# Date            0.000117
# AveragePrice    0.005596
# Total Volume    0.087954
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# region          0.000030
# dtype: float64

# %% [markdown]
# # Outliers

# %%
#Checking the outliers again

df1.boxplot(figsize=[10,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
print(np.where(z>3))
# Out:
# (array([  265,   398,   645,   662,  1423,  1423,  1726,  1834,  1834,
#         1882,  1931,  2584,  2673,  2673,  3035,  3056,  3092,  3166,
#         3222,  3320,  3836,  3898,  4196,  4930,  4930,  4939,  4939,
#         4939,  5008,  5036,  5089,  5150,  5273,  5295,  5690,  5697,
#         5924,  6062,  6748,  7026,  7055,  7066,  7091,  7102,  7283,
#         7283,  7638,  7641,  7641,  7784,  7980,  7980,  8233,  8367,
#         8752,  8752,  8872,  8872,  9045,  9052,  9204,  9216,  9312,
#         9350,  9398,  9417,  9588,  9716,  9894,  9960, 10033, 10033,
#        10141, 10260, 10317, 10454, 10610, 10610, 10782, 11033, 11585,
#        11733, 11971, 12006, 12006, 12760, 12848, 12848, 12911, 12917,
#        13022, 13324, 13468, 13757, 13772, 13772, 13785, 13785, 13886,
#        14168, 14279, 14349, 14513, 14513, 14774, 14774, 14922, 14922,
#        14922, 14922, 15051, 15179, 15263, 15339, 15500, 15753, 15753,
# ...

# %%
#checking the shape of the data

dff=df1[(z<3).all(axis = 1)]
print(df1.shape)
print(dff.shape)
# Out:
# (18249, 11)
# (18142, 11)

# %%
#checking for how much data we lost
loss_percent=(18249-18142)/18249*100
print(loss_percent)
# Out:
# 0.5863334977259027

# %% [markdown]
# We lost less than 1 percent of data, which is not bad.

# %% [markdown]
# # Seprate independent variable and target variable

# %%
x = dff.drop("AveragePrice", axis=1)
y = dff["AveragePrice"]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler() #Initializting MinMaxScaler
new = scale.fit(x)  #fitting our data into MinMaxScaller
scale_x = new.transform(x) #Transforming the data
#Setting up the coulumns after Scaling
scaled_x = pd.DataFrame(scale_x, index=x.index, columns=x.columns)
x=scaled_x
x.head() #Priting top 5 rows of our data
# Out:
#            Date  Total Volume      4046      4225      4770  Total Bags  \
# 9181   0.285714      0.301706  0.352875  0.325668  0.000000    0.279980
# 1013   0.154762      0.589454  0.426739  0.589814  0.685415    0.549910
# 14625  0.375000      0.719345  0.619716  0.669348  0.661501    0.742563
# 15234  0.833333      0.363484  0.272932  0.375633  0.000000    0.378851
# 18247  0.940476      0.401232  0.359483  0.355664  0.486588    0.431197
#
#        Small Bags  Large Bags  XLarge Bags    region
# 9181     0.198264    0.341318     0.000000  0.018868
# 1013     0.518999    0.538689     0.919681  0.358491
# 14625    0.680587    0.768122     0.000000  0.962264
# 15234    0.347751    0.404651     0.000000  0.169811
# 18247    0.448444    0.168280     0.000000  1.000000

# %% [markdown]
# After Scaling our data is in 0 to 1 range. It's now very convenient to train and test our data

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_Score=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    predrf = LR.predict(x_test)
    score = r2_score(y_test, predrf)
    if score>maxR2_Score:
        maxR2_Score=score
        maxRS=i
print("Best accuracy is",maxR2_Score," on Random_state ",maxRS)
# Out:
# Best accuracy is 0.5178794105633924  on Random_state  180

# %% [markdown]
# # Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=180)

# %% [markdown]
# # Finding Best Algorithm

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
model=[LinearRegression(),RandomForestRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),GradientBoostingRegressor(),Ridge(),SVR()]

# %%
for m in model:
    print("******")
    print("|||||||||||")
    print('accuracy score of ->', m)
    m.fit(x_train,y_train)
    pred = m.predict(x_test)
    print("R2 Score:                ", r2_score(y_test,pred))
    print("Mean Absolute Error:     ", mean_absolute_error(y_test,pred))
    print("Mean Squared error:      ", mean_squared_error(y_test,pred))
    print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,pred)))
    score=cross_val_score(m,x,y,cv=8)
    print(score)
    print("cross validation score:  ",score.mean())
    print("Difference between R2 score and cross validatio score is - ",r2_score(y_test,pred)-abs(score.mean()))
    print("|||||||||")
    print("*********")
# Out:
# ******
# |||||||||||
# accuracy score of -> LinearRegression()
# R2 Score:                 0.5178794105633924
# Mean Absolute Error:      0.5512471211030658
# Mean Squared error:       0.47215506961368575
# Root Mean Squared Error:  0.6871354084994352
# [0.49795666 0.51166985 0.50127047 0.4827505  0.50268212 0.50188373
#  0.50362543 0.5271828 ]
# cross validation score:   0.5036276946933307
# Difference between R2 score and cross validatio score is -  0.014251715870061687
# |||||||||
# *********
# ******
# |||||||||||
# accuracy score of -> RandomForestRegressor()
# R2 Score:                 0.9040701048003739
# Mean Absolute Error:      0.2191414310077418
# Mean Squared error:       0.09394700690742551
# Root Mean Squared Error:  0.3065077599465069
# [0.90586049 0.91159376 0.914372   0.92063149 0.91563204 0.9084141
#  0.90791507 0.91982499]
# cross validation score:   0.9130304912777435
# Difference between R2 score and cross validatio score is -  -0.00896038647736963
# |||||||||
# ...

# %% [markdown]
# Random Forest Regressor have height Accuracy and Cross validation score i.e. 90%

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

parameters = {'max_depth': np.arange(2,20), 'max_features': ['sqrt','auto', 'log2'], 'n_estimators': [100,200,500],'criterion' :['mse','mae'] }

# %%
clf = RandomizedSearchCV(RandomForestRegressor(), parameters, cv=1)
clf.fit(x_train, y_train)
clf.best_params_  #Best parameters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbaeaae8f3cb> in <module>
# ----> 1 clf = RandomizedSearchCV(RandomForestRegressor(), parameters, cv=1)
#       2 clf.fit(x_train, y_train)
#       3 clf.best_params_  #Best parameters
#
# NameError: name 'RandomizedSearchCV' is not defined

# %%
clf_pred = clf.best_estimator_.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bf63d8b2ffb6> in <module>
# ----> 1 clf_pred = clf.best_estimator_.predict(x_test)
#
# NameError: name 'clf' is not defined

# %%
r2_score(y_test, clf_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4b342dd0c46b> in <module>
# ----> 1 r2_score(y_test, clf_pred)
#
# NameError: name 'r2_score' is not defined

# %%
Saving the model
# Out:
#   File "<ipython-input-4-1bbd8497504c>", line 1
#     Saving the model
#            ^
# SyntaxError: invalid syntax

# %%
import joblib
joblib.dump(clf.best_estimator_,"Avacado.obj")
RF_from_joblib=joblib.load('Avacado.obj')
Predicted = RF_from_joblib.predict(x_test)
Predicted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e5035447e492> in <module>
#       1 import joblib
# ----> 2 joblib.dump(clf.best_estimator_,"Avacado.obj")
#       3 RF_from_joblib=joblib.load('Avacado.obj')
#       4 Predicted = RF_from_joblib.predict(x_test)
#       5 Predicted
#
# NameError: name 'clf' is not defined

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame([RF_from_joblib.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, Predicted, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(Predicted), max(y_test))
p2 = min(min(Predicted), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual AveragePrice', fontsize=15)
plt.ylabel('Predicted AveragePrice', fontsize=15)
plt.axis('equal')
plt.show()
