# %% [markdown]
# # ibm-hr-analytics-employee-attrition-performance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/ibm-hr-analytics-employee-attrition-performance.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# Problem: how does HR Analytics help in analyzing attrition?
#it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#no null values in the data set

# %%
sns.countplot(x=df['Attrition'])
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#around 237 employee have left the given company and rest stayed.

# %%
sns.countplot(x=df['Gender'])
print(df['Gender'].value_counts())
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#males are more than than the females in attrition

# %%
sns.countplot(x=df['Department'])
print(df['Department'].value_counts())
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#more people are in research & development department.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['EducationField'])
print(df['EducationField'].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#most peoples are from life sciences background and least are from human resource.

# %%
sns.countplot(x=df['Over18'])
# Out:
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %%
#As all the population are above 18 so we can drop this column as there is no use of this.

# %%
df.drop(['Over18'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 34)

# %%
sns.countplot(df['TotalWorkingYears'])
print(df['TotalWorkingYears'].value_counts())
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 1      81
# 7      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 13     36
# 11     36
# 21     34
# 17     33
# 14     31
# 2      31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 27      7
# 30      7
# 33      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
#There are maximum number of employees who have total working years in company is 10 years and minimum working years is 38years

# %%
sns.countplot(df['BusinessTravel'])
print(df['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
sns.countplot(df['MaritalStatus'])
print(df['MaritalStatus'].value_counts())
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#There are more married employees as compare to single and divorced

# %% [markdown]
# # For Outliers

# %%
df['TotalWorkingYears'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#outliers are present in this col of dataset.

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True,cmap='winter')
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
df['JobLevel']=np.log1p(df['JobLevel'])

# %%
df['YearsSinceLastPromotion']=np.log1p(df['YearsSinceLastPromotion'])

# %%
df['YearsAtCompany']=np.log1p(df['YearsAtCompany'])

# %%
df['PerformanceRating']=np.log1p(df['PerformanceRating'])

# %%
df['TotalWorkingYears']=np.log1p(df['TotalWorkingYears'])

# %%
sns.distplot(df['YearsSinceLastPromotion'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
#skewness removed

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears          -0.622175
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.207708
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     0.718805
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
#correcting all the skewness.

# %%
#Bivirate analysis
plt.figure(figsize=(16,8))
sns.countplot(x='Age',hue='Attrition',data=df)
print(df.groupby('Age')['Attrition'].value_counts())
# Out:
# Age  Attrition
# 18   No            4
#      Yes           4
# 19   Yes           6
#      No            3
# 20   Yes           6
#                   ..
# 57   No            4
# 58   No            9
#      Yes           5
# 59   No           10
# 60   No            5
# Name: Attrition, Length: 82, dtype: int64

# %%
#age wise attrition rate.

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Gender',hue='Attrition',data=df)
print(df.groupby('Gender')['Attrition'].value_counts())
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: Attrition, dtype: int64

# %%
#more males have left the company then females.

# %%
plt.figure(figsize=(16,8))
sns.lineplot(x='Age',y='HourlyRate',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='HourlyRate'>

# %%
plt.figure(figsize=(16,8))
sns.lineplot(y='DailyRate',x='MonthlyIncome',data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='DailyRate'>

# %%
#high fluctions in dailyrate and monthly income

# %%
#sns.pairplot(df)

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Department',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
#people who are in reseach department have more attrition rate

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='BusinessTravel',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
#who travel rarelt are more attrition rate

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='EducationField',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
#people who are in life sciences have more attrition rate

# %% [markdown]
# # Remove Outliers

# %%
df.drop(['Age'],axis=1,inplace=True)

# %%
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
df.drop(['StandardHours'],axis=1,inplace=True)

# %%
df['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
df.drop(['EmployeeCount'],axis=1,inplace=True)

# %%
df['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
df.drop(['EmployeeNumber'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Attrition     BusinessTravel  DailyRate              Department  \
# 0       Yes      Travel_Rarely       1102                   Sales
# 1        No  Travel_Frequently        279  Research & Development
# 2       Yes      Travel_Rarely       1373  Research & Development
# 3        No  Travel_Frequently       1392  Research & Development
# 4        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 0  Female          94  ...           1.386294                         1
# 1    Male          61  ...           1.609438                         4
# 2    Male          92  ...           1.386294                         2
# 3  Female          56  ...           1.386294                         3
# 4    Male          40  ...           1.386294                         4
#
#   StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                0           2.197225                     0                1
# 1                1           2.397895                     3                3
# 2                0           2.079442                     3                3
# 3                0           2.197225                     3                3
# 4                1           1.945910                     3                3
#
#    YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0        1.945910                   4                0.000000
# 1        2.397895                   7                0.693147
# 2        0.000000                   0                0.000000
# 3        2.197225                   7                1.386294
# 4        1.098612                   2                1.098612
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (1470, 30)

# %%
df.dtypes
# Out:
# Attrition                    object
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                    float64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# OverTime                     object
# PercentSalaryHike             int64
# PerformanceRating           float64
# RelationshipSatisfaction      int64
# StockOptionLevel              int64
# TotalWorkingYears           float64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany              float64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion     float64
# YearsWithCurrManager          int64
# dtype: object

# %% [markdown]
# # Encoding the values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Attrition']=le.fit_transform(df['Attrition'])

# %%
df['OverTime']=le.fit_transform(df['OverTime'])

# %%
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
df['JobRole']=le.fit_transform(df['JobRole'])

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['EducationField']=le.fit_transform(df['EducationField'])

# %%
df['Department']=le.fit_transform(df['Department'])

# %%
df['BusinessTravel']=le.fit_transform(df['BusinessTravel'])

# %%
df.dtypes
# Out:
# Attrition                     int32
# BusinessTravel                int32
# DailyRate                     int64
# Department                    int32
# DistanceFromHome              int64
# Education                     int64
# EducationField                int32
# EnvironmentSatisfaction       int64
# Gender                        int32
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                    float64
# JobRole                       int32
# JobSatisfaction               int64
# MaritalStatus                 int32
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# OverTime                      int32
# PercentSalaryHike             int64
# PerformanceRating           float64
# RelationshipSatisfaction      int64
# StockOptionLevel              int64
# TotalWorkingYears           float64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany              float64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion     float64
# YearsWithCurrManager          int64
# dtype: object

# %% [markdown]
# # z score outlier removal

# %%
from scipy.stats import zscore

# %%
threshold=3
z=np.abs(zscore(df))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (1434, 30)

# %%
#Percentage of data loss

# %%
Data_loss=((1470-1434)/1470)*100

# %%
Data_loss
# Out:
# 2.4489795918367347

# %% [markdown]
# # Separating the columns into features and target:

# %%
x=df_new.drop(['Attrition'],axis=1)

# %%
y=df_new['Attrition']

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x=pd.DataFrame(x)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score,auc
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier,BaggingClassifier
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')

# %%
#Define a function to try different train test folds
model=[LogisticRegression(),SVC(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier()]

# %%
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=.80,random_state=42)
    m.fit(x_train,y_train)
    print(m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('the accuracy score of',m,'is:',accuracy_score(y_test,predm))
    print('the confusion matrix of',m,'is:',confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('_________________________________________________________________')
# Out:
# 0.8814298169136879
# the accuracy score of LogisticRegression() is: 0.8466898954703833
# the confusion matrix of LogisticRegression() is: [[227  11]
#  [ 33  16]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       238
#            1       0.59      0.33      0.42        49
#
#     accuracy                           0.85       287
#    macro avg       0.73      0.64      0.67       287
# weighted avg       0.83      0.85      0.83       287
#
# _________________________________________________________________
# 0.916303400174368
# the accuracy score of SVC() is: 0.8536585365853658
# the confusion matrix of SVC() is: [[237   1]
#  [ 41   8]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       238
#            1       0.89      0.16      0.28        49
#
#     accuracy                           0.85       287
#    macro avg       0.87      0.58      0.60       287
# weighted avg       0.86      0.85      0.81       287
#
# _________________________________________________________________
# 0.8700959023539668
# the accuracy score of KNeighborsClassifier() is: 0.8432055749128919
# the confusion matrix of KNeighborsClassifier() is: [[236   2]
#  [ 43   6]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       238
#            1       0.75      0.12      0.21        49
#
#     accuracy                           0.84       287
#    macro avg       0.80      0.56      0.56       287
# weighted avg       0.83      0.84      0.79       287
#
# _________________________________________________________________
# 1.0
# the accuracy score of DecisionTreeClassifier() is: 0.7735191637630662
# the confusion matrix of DecisionTreeClassifier() is: [[204  34]
#  [ 31  18]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86       238
#            1       0.35      0.37      0.36        49
#
#     accuracy                           0.77       287
#    macro avg       0.61      0.61      0.61       287
# weighted avg       0.78      0.77      0.78       287
#
# _________________________________________________________________
# 1.0
# the accuracy score of RandomForestClassifier() is: 0.8501742160278746
# the confusion matrix of RandomForestClassifier() is: [[236   2]
#  [ 41   8]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       238
#            1       0.80      0.16      0.27        49
#
#     accuracy                           0.85       287
#    macro avg       0.83      0.58      0.59       287
# weighted avg       0.84      0.85      0.81       287
#
# _________________________________________________________________
# 0.9075850043591979
# the accuracy score of AdaBoostClassifier() is: 0.8327526132404182
# the confusion matrix of AdaBoostClassifier() is: [[224  14]
#  [ 34  15]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       238
#            1       0.52      0.31      0.38        49
#
#     accuracy                           0.83       287
#    macro avg       0.69      0.62      0.64       287
# weighted avg       0.81      0.83      0.81       287
#
# _________________________________________________________________
# 0.953792502179599
# the accuracy score of GradientBoostingClassifier() is: 0.8641114982578397
# the confusion matrix of GradientBoostingClassifier() is: [[234   4]
#  [ 35  14]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       238
#            1       0.78      0.29      0.42        49
#
#     accuracy                           0.86       287
#    macro avg       0.82      0.63      0.67       287
# weighted avg       0.85      0.86      0.84       287
#
# _________________________________________________________________
# 1.0
# the accuracy score of ExtraTreesClassifier() is: 0.8432055749128919
# the confusion matrix of ExtraTreesClassifier() is: [[235   3]
#  [ 42   7]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       238
#            1       0.70      0.14      0.24        49
#
#     accuracy                           0.84       287
#    macro avg       0.77      0.57      0.57       287
# weighted avg       0.82      0.84      0.80       287
#
# _________________________________________________________________
# 0.979075850043592
# the accuracy score of BaggingClassifier() is: 0.867595818815331
# the confusion matrix of BaggingClassifier() is: [[236   2]
#  [ 36  13]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       238
#            1       0.87      0.27      0.41        49
#
#     accuracy                           0.87       287
#    macro avg       0.87      0.63      0.67       287
# weighted avg       0.87      0.87      0.84       287
#
# _________________________________________________________________

# %%
#so accoarding to our model adaboostclassifier is giving the best accuracy with least errors.

# %% [markdown]
# # Hyperparametric tunning

# %%
svc=SVC()
parameters={'kernel':['rbf','linear','poly'],'random_state':range(40,100)}
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'kernel': 'linear', 'random_state': 40}

# %%
parameters={'criterion':['gini','entropy'],'random_state':range(42,60)}
dtc=DecisionTreeClassifier()
clf=GridSearchCV(dtc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'random_state': 59}

# %%
parameters={'criterion':['friedman_mse','mse','mae'],'n_estimators':[100,200,300]}
gbc=GradientBoostingClassifier()
clf=GridSearchCV(gbc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'n_estimators': 200}

# %% [markdown]
# # Cross Validation

# %%
for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='accuracy')
    print('Model',m)
    print('score',score)
    print('mean score of',m,'is:',score.mean())
    print('standard deviation of',m,'is-',score.std())
    print('_________________________________________________________________')
# Out:
# Model LogisticRegression()
# score [0.87456446 0.85017422 0.8641115  0.87456446 0.86713287]
# mean score of LogisticRegression() is: 0.8661095002558419
# standard deviation of LogisticRegression() is- 0.008965994215579252
# _________________________________________________________________
# Model SVC()
# score [0.85714286 0.85017422 0.87108014 0.86062718 0.88111888]
# mean score of SVC() is: 0.8640286542725567
# standard deviation of SVC() is- 0.01088787398748229
# _________________________________________________________________
# Model KNeighborsClassifier()
# score [0.84320557 0.83972125 0.84320557 0.85017422 0.85664336]
# mean score of KNeighborsClassifier() is: 0.8465899953704831
# standard deviation of KNeighborsClassifier() is- 0.006066381415697241
# _________________________________________________________________
# Model DecisionTreeClassifier()
# score [0.77700348 0.72125436 0.81533101 0.77700348 0.81818182]
# mean score of DecisionTreeClassifier() is: 0.7817548305353184
# standard deviation of DecisionTreeClassifier() is- 0.03509912637112272
# _________________________________________________________________
# Model RandomForestClassifier()
# score [0.8466899  0.85365854 0.86062718 0.85017422 0.85664336]
# mean score of RandomForestClassifier() is: 0.8535586364854659
# standard deviation of RandomForestClassifier() is- 0.004860527921018284
# _________________________________________________________________
# Model AdaBoostClassifier()
# score [0.8641115  0.85365854 0.87108014 0.87804878 0.87412587]
# mean score of AdaBoostClassifier() is: 0.8682049657659412
# standard deviation of AdaBoostClassifier() is- 0.008585796940298398
# _________________________________________________________________
# Model GradientBoostingClassifier()
# score [0.8466899  0.87804878 0.87108014 0.84320557 0.88461538]
# mean score of GradientBoostingClassifier() is: 0.8647279549718572
# standard deviation of GradientBoostingClassifier() is- 0.016744485246777196
# _________________________________________________________________
# Model ExtraTreesClassifier()
# score [0.85365854 0.85017422 0.8641115  0.86062718 0.86363636]
# mean score of ExtraTreesClassifier() is: 0.8584415584415584
# standard deviation of ExtraTreesClassifier() is- 0.005570231570384363
# _________________________________________________________________
# Model BaggingClassifier()
# score [0.8466899  0.85017422 0.85365854 0.83623693 0.87062937]
# mean score of BaggingClassifier() is: 0.8514777905021808
# standard deviation of BaggingClassifier() is- 0.011211116208239096
# _________________________________________________________________

# %%
#saving the best model ADABOOSTCLASSIFIER() as of now.

# %%
LR=LogisticRegression(C=10,random_state=42)
DTC=DecisionTreeClassifier(criterion='gini',random_state=44)
GBC=GradientBoostingClassifier(criterion='friedman_mse',random_state=42,learning_rate=0.1,n_estimators=250,max_depth=4)
BC=BaggingClassifier(n_estimators=250)

# %%
models=[]
models.append(('LogisticRegression',LR))
models.append(('DecisionTreeClassifier',DTC))
models.append(('GradientBoostingClassifier',GBC))
models.append(('BaggingClassifier',BC))

# %% [markdown]
# # AUC AND ROC

# %%
Model=[]
score=[]
CVS=[]
ROC_Score=[]
for name,model in models:
    print('__________,name,__________')
    print('\n')
    Model.append(name)

    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)

    AS=accuracy_score(y_test,pred)
    print('accuracy score',AS)
    score.append(AS*100)
    print('\n')

    cross_val=cross_val_score(model,x,y,cv=15,scoring='accuracy').mean()
    print('cross validation score',cross_val)
    CVS.append(cross_val*100)
    print('\n')

    true_positive_rate,false_positive_rate,threshold=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('ROC_AUC_SCORE',roc_auc)
    ROC_Score.append(roc_auc*100)
    print('\n')

    cm=confusion_matrix(y_test,pred)
    print(cm)
    print('\n')

    print('Classification report',classification_report(y_test,pred))
    print('\n')
# Out:
# __________,name,__________
#
#
# LogisticRegression(C=10, random_state=42)
# accuracy score 0.8466898954703833
#
#
# cross validation score 0.8689254385964912
#
#
# ROC_AUC_SCORE 0.3598439375750301
#
#
# [[227  11]
#  [ 33  16]]
#
#
# Classification report               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       238
#            1       0.59      0.33      0.42        49
#
#     accuracy                           0.85       287
#    macro avg       0.73      0.64      0.67       287
# weighted avg       0.83      0.85      0.83       287
#
#
#
# __________,name,__________
#
#
# DecisionTreeClassifier(random_state=44)
# accuracy score 0.7630662020905923
#
#
# cross validation score 0.7796710526315791
#
#
# ROC_AUC_SCORE 0.385954381752701
#
#
# [[200  38]
#  [ 30  19]]
#
#
# Classification report               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       238
#            1       0.33      0.39      0.36        49
#
#     accuracy                           0.76       287
#    macro avg       0.60      0.61      0.61       287
# weighted avg       0.78      0.76      0.77       287
#
#
#
# __________,name,__________
#
#
# GradientBoostingClassifier(max_depth=4, n_estimators=250, random_state=42)
# accuracy score 0.8606271777003485
#
#
# cross validation score 0.8605628654970761
#
#
# ROC_AUC_SCORE 0.3676470588235294
#
#
# [[233   5]
#  [ 35  14]]
#
#
# Classification report               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       238
#            1       0.74      0.29      0.41        49
#
#     accuracy                           0.86       287
#    macro avg       0.80      0.63      0.67       287
# weighted avg       0.85      0.86      0.83       287
#
#
#
# __________,name,__________
#
#
# BaggingClassifier(n_estimators=250)
# accuracy score 0.8501742160278746
#
#
# cross validation score 0.8598684210526315
#
#
# ROC_AUC_SCORE 0.3820528211284513
#
#
# [[231   7]
#  [ 36  13]]
#
#
# Classification report               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91       238
#            1       0.65      0.27      0.38        49
#
#     accuracy                           0.85       287
#    macro avg       0.76      0.62      0.65       287
# weighted avg       0.83      0.85      0.82       287

# %%
ABC=AdaBoostClassifier()

# %%
y_pred_prob=LR.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([7.53351883e-02, 2.20912894e-02, 6.72378873e-01, 2.07081013e-01,
#        1.89814332e-01, 1.08234050e-01, 5.45327732e-01, 5.63320215e-01,
#        1.14791771e-01, 1.45662022e-02, 2.49489862e-01, 1.92799580e-02,
#        2.92562019e-02, 2.33555090e-01, 1.20830027e-01, 7.66029080e-02,
#        2.35132688e-01, 3.29506187e-02, 1.63904165e-02, 1.95714576e-01,
#        2.90496768e-02, 3.83861694e-01, 5.73948785e-01, 1.24223304e-02,
#        1.47980279e-01, 9.63126592e-03, 2.39114625e-02, 3.56529316e-02,
#        3.46448577e-01, 1.94420834e-01, 2.38751004e-02, 6.60130968e-02,
#        4.26433303e-01, 2.35346360e-01, 6.12329835e-02, 3.41758068e-01,
#        7.50124831e-03, 7.83049457e-02, 3.84834540e-01, 1.38524968e-01,
#        0.52521008, 0.57563025, 0.57563025, 0.58403361, 0.58403361,
#        0.69747899, 0.69747899, 0.96218487, 0.96218487, 0.97058824,
#        0.97058824, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.02040816, 0.04081633, 0.04081633, 0.12244898,
#        0.12244898, 0.14285714, 0.14285714, 0.26530612, 0.26530612,
#        0.30612245, 0.30612245, 0.34693878, 0.34693878, 0.36734694,
#        0.36734694, 0.40816327, 0.40816327, 0.44897959, 0.44897959,
#        0.46938776, 0.46938776, 0.55102041, 0.55102041, 0.57142857,
#        0.57142857, 0.6122449 , 0.6122449 , 0.63265306, 0.63265306,
#        0.65306122, 0.65306122, 0.67346939, 0.67346939, 0.69387755,
#        0.69387755, 0.71428571, 0.71428571, 0.73469388, 0.73469388,
#        0.75510204, 0.75510204, 0.7755102 , 0.7755102 , 0.81632653,
#        0.81632653, 0.83673469, 0.83673469, 0.85714286, 0.85714286,
#        0.87755102, 0.87755102, 0.91836735, 0.91836735, 0.93877551,
#        0.93877551, 0.95918367, 0.95918367, 0.97959184, 0.97959184,
#        1.        , 1.        ])

# %%
thresholds
# Out:
# array([1.93278460e+00, 9.32784598e-01, 8.19193498e-01, 7.85345391e-01,
#        7.47857019e-01, 7.36491689e-01, 7.30590714e-01, 6.98248077e-01,
#        5.74605302e-01, 5.63320215e-01, 5.58014940e-01, 5.34010542e-01,
#        4.98405098e-01, 4.70267097e-01, 4.69628121e-01, 4.42475497e-01,
#        4.34599036e-01, 3.78996856e-01, 3.73688150e-01, 3.61456156e-01,
#        3.57982622e-01, 3.46448577e-01, 3.39604027e-01, 3.25461803e-01,
#        3.23133953e-01, 3.04819975e-01, 2.96781956e-01, 2.82338114e-01,
#        2.80885762e-01, 2.35346360e-01, 2.35132688e-01, 2.24991688e-01,
#        2.21593307e-01, 2.20479250e-01, 2.18437834e-01, 2.15012949e-01,
#        2.14482412e-01, 2.03179351e-01, 2.03041939e-01, 1.99678642e-01,
#        1.95714576e-01, 1.53214368e-01, 1.52172710e-01, 1.38520842e-01,
#        1.38193832e-01, 1.00349754e-01, 1.00290996e-01, 7.83049457e-02,
#        7.66029080e-02, 7.56497710e-02, 7.53351883e-02, 6.60130968e-02,
#        6.56468884e-02, 6.34232414e-02, 6.12329835e-02, 3.98011030e-02,
#        3.96582307e-02, 7.50124831e-03, 7.12074973e-03, 6.47036732e-03,
#        6.13152719e-03, 1.65915373e-04])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('logistic regression')
plt.show()

# %%
#blue line greater than dotted line---->\\

auc_score=roc_auc_score(y_test,LR.predict(x_test))

# %%
auc_score
# Out:
# 0.6401560624249699

# %%
#value .6 is the accurate score for this model

# %% [markdown]
# # SAVING THE MODEL

# %%
import joblib

# %%
joblib.dump(ABC,'ibm-hr-analytics-employee-attrition-performance.csv.pkl')
# Out:
# ['ibm-hr-analytics-employee-attrition-performance.csv.pkl']
